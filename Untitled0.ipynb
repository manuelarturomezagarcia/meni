# %% [markdown]
# <a href="https://colab.research.google.com/github/manuelarturomezagarcia/meni/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
data_yaml = """\
path: /content
train: imagenes/train
val: imagenes/vals

names:
  0: arma
"""

with open('/content/data.yaml', 'w') as f:
    f.write(data_yaml)

print("✅ Archivo 'data.yaml' creado correctamente.")
# Out:
# ✅ Archivo 'data.yaml' creado correctamente.

# %%
import os

# Mostrar estructura de carpetas en /content
for root, dirs, files in os.walk("/content"):
    level = root.replace("/content", "").count(os.sep)
    indent = " " * 2 * (level)
    print(f"{indent}{os.path.basename(root)}/")
    subindent = " " * 2 * (level + 1)
    for f in files:
        print(f"{subindent}{f}")
# Out:
# content/
#   untitled
#   yolov8n.pt
#   data.yaml
#   .config/
#     active_config
#     .last_opt_in_prompt.yaml
#     config_sentinel
#     .last_survey_prompt.yaml
#     gce
#     .last_update_check.json
#     hidden_gcloud_config_universe_descriptor_data_cache_configs.db
#     default_configs.db
#     logs/
#       2025.05.14/
#         13.38.05.736741.log
#         13.37.56.530848.log
#         13.38.07.566408.log
#         13.38.16.976468.log
#         13.38.17.706556.log
#         13.37.34.542601.log
#     configurations/
#       config_default
#   .ipynb_checkpoints/
# content/
#   .ipynb_checkpoints/
#   labels/
#     .ipynb_checkpoints/
#     vals/
#       -30_jpeg_jpg.rf.f63972963193ac42cb8490b80e2f690e.txt
#       -110_jpeg_jpg.rf.c6310948a0d06472c7f718db0521a38c.txt
#       -62_jpeg_jpg.rf.ca87a5e7923c100c5e6b2fdaf0bdedbc.txt
#       -9_jpeg_jpg.rf.755217265af6c35776e2984f419c136c.txt
#     train/
#       -116_jpeg_jpg.rf.de32dd042f9f198f870fdfe9c81ffb65.txt
# ...
